# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, r2_score
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import cross_val_score

# %%
df = pd.read_csv("data_hasil_olah_Aave.csv")
df.head()
# Out:
#    SNo  Name Symbol                 Date       High        Low       Open  \
# 0   20  Aave   AAVE  2020-10-24 23:59:59  42.439706  38.728822  41.686637
# 1   21  Aave   AAVE  2020-10-25 23:59:59  40.928509  37.601201  39.455022
# 2   22  Aave   AAVE  2020-10-26 23:59:59  39.163864  35.071968  37.904763
# 3   23  Aave   AAVE  2020-10-27 23:59:59  38.869182  34.469635  36.033914
# 4   24  Aave   AAVE  2020-10-28 23:59:59  35.564022  32.000059  34.871536
#
#        Close        Volume     Marketcap  log_return        ma5       ma20  \
# 0  39.455022  5.765817e+07  4.214211e+08   -0.737283  37.302737  43.395799
# 1  37.904761  4.397045e+07  4.048626e+08   -0.562345  38.447685  42.630075
# 2  36.033922  5.030722e+07  3.848801e+08   -0.685704  38.622399  42.311691
# 3  34.871531  5.858131e+07  3.724646e+08   -0.476899  37.990375  42.051069
# 4  32.394083  6.053387e+07  3.460028e+08   -0.956042  36.131864  41.482550
#
#    ma_ratio  volatility       rsi
# 0 -1.074054    0.526385 -0.981832
# 1 -0.841598   -0.028793 -1.120489
# 2 -0.781608   -0.030617 -1.480912
# 3 -0.833117   -0.335354 -1.483095
# 4 -1.011292   -1.505724 -1.609274

# %%
# df.head()

# %%
df['log_return'] = np.log(df['Close'] / df['Close'].shift(1))
df['target'] = df['log_return'].shift(-1)

df = df.dropna()

features = ['log_return','Volume']

X = df[features]
y = df['target']

# %%
import gymnasium as gym
from gymnasium import spaces
import numpy as np

class TradingEnv(gym.Env):
    def __init__(self, df, window_size=10):
        super(TradingEnv, self).__init__()
        
        self.df = df
        self.window_size = window_size
        self.current_step = window_size
        self.transaction_cost = 0.0005
        
        # 0 = Short, 1 = Long
        self.action_space = spaces.Discrete(2)
        
        # window log_return
        self.observation_space = spaces.Box(
            low=-np.inf,
            high=np.inf,
            shape=(window_size,),
            dtype=np.float32
        )
        
        self.position = 0  # -1 short, 1 long
        self.balance = 1.0

    def reset(self, seed=None, options=None):
        self.current_step = self.window_size
        self.position = 0
        self.balance = 1.0
        return self._get_obs(), {}

    def _get_obs(self):
        return self.df['log_return'].iloc[
            self.current_step-self.window_size:self.current_step
        ].values.astype(np.float32)

    def step(self, action):
        done = False
        
        # ubah action jadi posisi
        new_position = 1 if action == 1 else -1
        
        log_return = self.df['log_return'].iloc[self.current_step]
        
        reward = new_position * log_return
        
        # biaya transaksi kalau ganti posisi
        if new_position != self.position:
            reward -= self.transaction_cost
        
        self.balance *= (1 + reward)
        
        self.position = new_position
        self.current_step += 1
        
        if self.current_step >= len(self.df)-1:
            done = True
            
        return self._get_obs(), reward, done, False, {}

# %%
from stable_baselines3 import PPO

env = TradingEnv(df)

model = PPO(
    "MlpPolicy",
    env,
    verbose=1,
    learning_rate=0.0003,
    n_steps=64,
    batch_size=32
)

model.learn(total_timesteps=20000)
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ----------------------------
# | time/              |     |
# |    fps             | 440 |
# |    iterations      | 1   |
# |    time_elapsed    | 0   |
# |    total_timesteps | 64  |
# ----------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 418           |
# |    iterations           | 2             |
# |    time_elapsed         | 0             |
# |    total_timesteps      | 128           |
# | train/                  |               |
# |    approx_kl            | 1.2873672e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.693        |
# |    explained_variance   | -0.112        |
# |    learning_rate        | 0.0003        |
# |    loss                 | 0.0135        |
# |    n_updates            | 10            |
# |    policy_gradient_loss | -0.00105      |
# |    value_loss           | 0.0391        |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 438           |
# |    iterations           | 3             |
# |    time_elapsed         | 0             |
# |    total_timesteps      | 192           |
# | train/                  |               |
# |    approx_kl            | 1.3990328e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.693        |
# |    explained_variance   | -0.063        |
# |    learning_rate        | 0.0003        |
# |    loss                 | 0.0135        |
# |    n_updates            | 20            |
# |    policy_gradient_loss | -0.000477     |
# |    value_loss           | 0.0381        |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 243          |
# |    ep_rew_mean          | 0.761        |
# | time/                   |              |
# |    fps                  | 447          |
# |    iterations           | 4            |
# |    time_elapsed         | 0            |
# |    total_timesteps      | 256          |
# | train/                  |              |
# |    approx_kl            | 1.959037e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.693       |
# |    explained_variance   | 0.0477       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0153       |
# |    n_updates            | 30           |
# |    policy_gradient_loss | -0.000622    |
# |    value_loss           | 0.0371       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 243          |
# |    ep_rew_mean          | 0.761        |
# | time/                   |              |
# |    fps                  | 458          |
# |    iterations           | 5            |
# |    time_elapsed         | 0            |
# |    total_timesteps      | 320          |
# | train/                  |              |
# |    approx_kl            | 3.770739e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.693       |
# |    explained_variance   | -0.0203      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0265       |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -0.0011      |
# |    value_loss           | 0.0574       |
# ------------------------------------------
# --------------------------------------------
# | rollout/                |                |
# |    ep_len_mean          | 243            |
# |    ep_rew_mean          | 0.761          |
# | time/                   |                |
# |    fps                  | 466            |
# |    iterations           | 6              |
# |    time_elapsed         | 0              |
# |    total_timesteps      | 384            |
# | train/                  |                |
# |    approx_kl            | 1.38655305e-05 |
# |    clip_fraction        | 0              |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -0.693         |
# |    explained_variance   | -0.0683        |
# |    learning_rate        | 0.0003         |
# |    loss                 | 0.00343        |
# |    n_updates            | 50             |
# |    policy_gradient_loss | -0.00039       |
# |    value_loss           | 0.0145         |
# --------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 243           |
# |    ep_rew_mean          | 0.761         |
# | time/                   |               |
# |    fps                  | 466           |
# |    iterations           | 7             |
# |    time_elapsed         | 0             |
# |    total_timesteps      | 448           |
# | train/                  |               |
# |    approx_kl            | 2.5115907e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.693        |
# |    explained_variance   | -0.139        |
# |    learning_rate        | 0.0003        |
# |    loss                 | 0.0121        |
# |    n_updates            | 60            |
# |    policy_gradient_loss | -0.000569     |
# |    value_loss           | 0.0333        |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 243          |
# |    ep_rew_mean          | 0.527        |
# | time/                   |              |
# |    fps                  | 457          |
# |    iterations           | 8            |
# |    time_elapsed         | 1            |
# |    total_timesteps      | 512          |
# | train/                  |              |
# |    approx_kl            | 3.258232e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.693       |
# |    explained_variance   | -0.0347      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0262       |
# |    n_updates            | 70           |
# |    policy_gradient_loss | -0.000996    |
# |    value_loss           | 0.0679       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 243          |
# |    ep_rew_mean          | 0.527        |
# | time/                   |              |
# |    fps                  | 447          |
# |    iterations           | 9            |
# |    time_elapsed         | 1            |
# |    total_timesteps      | 576          |
# | train/                  |              |
# |    approx_kl            | 4.133582e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.693       |
# |    explained_variance   | -0.293       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0142       |
# |    n_updates            | 80           |
# |    policy_gradient_loss | -0.00153     |
# |    value_loss           | 0.0428       |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 243           |
# |    ep_rew_mean          | 0.527         |
# | time/                   |               |
# |    fps                  | 450           |
# |    iterations           | 10            |
# |    time_elapsed         | 1             |
# |    total_timesteps      | 640           |
# | train/                  |               |
# |    approx_kl            | 5.3388998e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.693        |
# |    explained_variance   | -0.174        |
# |    learning_rate        | 0.0003        |
# |    loss                 | 0.00663       |
# |    n_updates            | 90            |
# |    policy_gradient_loss | -0.000804     |
# |    value_loss           | 0.0199        |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 243          |
# |    ep_rew_mean          | 0.527        |
# | time/                   |              |
# |    fps                  | 451          |
# |    iterations           | 11           |
# |    time_elapsed         | 1            |
# |    total_timesteps      | 704          |
# | train/                  |              |
# |    approx_kl            | 1.758337e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.693       |
# |    explained_variance   | 0.0187       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0157       |
# |    n_updates            | 100          |
# |    policy_gradient_loss | -0.000626    |
# |    value_loss           | 0.0312       |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 243           |
# |    ep_rew_mean          | -0.188        |
# | time/                   |               |
# |    fps                  | 451           |
# |    iterations           | 12            |
# |    time_elapsed         | 1             |
# |    total_timesteps      | 768           |
# | train/                  |               |
# |    approx_kl            | 4.0114857e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.693        |
# |    explained_variance   | 0.00586       |
# |    learning_rate        | 0.0003        |
# |    loss                 | 0.0297        |
# |    n_updates            | 110           |
# |    policy_gradient_loss | -0.000719     |
# |    value_loss           | 0.0999        |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 243          |
# |    ep_rew_mean          | -0.188       |
# | time/                   |              |
# |    fps                  | 453          |
# |    iterations           | 13           |
# |    time_elapsed         | 1            |
# |    total_timesteps      | 832          |
# | train/                  |              |
# |    approx_kl            | 6.867666e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.693       |
# |    explained_variance   | 0.214        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00956      |
# |    n_updates            | 120          |
# |    policy_gradient_loss | -0.00123     |
# |    value_loss           | 0.0388       |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 243           |
# |    ep_rew_mean          | -0.188        |
# | time/                   |               |
# |    fps                  | 454           |
# |    iterations           | 14            |
# |    time_elapsed         | 1             |
# |    total_timesteps      | 896           |
# | train/                  |               |
# |    approx_kl            | 0.00021094922 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.693        |
# |    explained_variance   | -0.0875       |
# |    learning_rate        | 0.0003        |
# |    loss                 | 0.00273       |
# |    n_updates            | 130           |
# |    policy_gradient_loss | -0.00239      |
# |    value_loss           | 0.0332        |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 243           |
# |    ep_rew_mean          | -0.188        |
# | time/                   |               |
# |    fps                  | 456           |
# |    iterations           | 15            |
# |    time_elapsed         | 2             |
# |    total_timesteps      | 960           |
# | train/                  |               |
# |    approx_kl            | 1.5577301e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.692        |
# |    explained_variance   | -0.823        |
# |    learning_rate        | 0.0003        |
# |    loss                 | 0.000834      |
# |    n_updates            | 140           |
# |    policy_gradient_loss | -0.000356     |
# |    value_loss           | 0.0141        |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 243           |
# |    ep_rew_mean          | -0.547        |
# | time/                   |               |
# |    fps                  | 457           |
# |    iterations           | 16            |
# |    time_elapsed         | 2             |
# |    total_timesteps      | 1024          |
# | train/                  |               |
# |    approx_kl            | 0.00017286651 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.691        |
# |    explained_variance   | -0.0475       |
# |    learning_rate        | 0.0003        |
# |    loss                 | 0.00464       |
# |    n_updates            | 150           |
# |    policy_gradient_loss | -0.0025       |
# |    value_loss           | 0.0325        |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 243           |
# |    ep_rew_mean          | -0.547        |
# | time/                   |               |
# |    fps                  | 459           |
# |    iterations           | 17            |
# |    time_elapsed         | 2             |
# |    total_timesteps      | 1088          |
# | train/                  |               |
# |    approx_kl            | 0.00018856674 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.69         |
# |    explained_variance   | -0.426        |
# |    learning_rate        | 0.0003        |
# |    loss                 | 0.0177        |
# |    n_updates            | 160           |
# |    policy_gradient_loss | -0.00106      |
# |    value_loss           | 0.0684        |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 243           |
# |    ep_rew_mean          | -0.547        |
# | time/                   |               |
# |    fps                  | 458           |
# |    iterations           | 18            |
# |    time_elapsed         | 2             |
# |    total_timesteps      | 1152          |
# | train/                  |               |
# |    approx_kl            | 0.00043080002 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.69         |
# |    explained_variance   | 0.0438        |
# |    learning_rate        | 0.0003        |
# |    loss                 | 0.00611       |
# |    n_updates            | 170           |
# |    policy_gradient_loss | -0.00215      |
# |    value_loss           | 0.0298        |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 243           |
# |    ep_rew_mean          | 0.184         |
# | time/                   |               |
# |    fps                  | 456           |
# |    iterations           | 19            |
# |    time_elapsed         | 2             |
# |    total_timesteps      | 1216          |
# | train/                  |               |
# |    approx_kl            | 0.00054283906 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.686        |
# |    explained_variance   | -0.0598       |
# |    learning_rate        | 0.0003        |
# |    loss                 | -0.00231      |
# |    n_updates            | 180           |
# |    policy_gradient_loss | -0.00201      |
# |    value_loss           | 0.012         |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 243          |
# |    ep_rew_mean          | 0.184        |
# | time/                   |              |
# |    fps                  | 455          |
# |    iterations           | 20           |
# |    time_elapsed         | 2            |
# |    total_timesteps      | 1280         |
# | train/                  |              |
# |    approx_kl            | 0.0005063582 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.68        |
# |    explained_variance   | -0.0401      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.04         |
# |    n_updates            | 190          |
# |    policy_gradient_loss | -0.00384     |
# |    value_loss           | 0.12         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 243          |
# |    ep_rew_mean          | 0.184        |
# | time/                   |              |
# |    fps                  | 450          |
# |    iterations           | 21           |
# |    time_elapsed         | 2            |
# |    total_timesteps      | 1344         |
# | train/                  |              |
# |    approx_kl            | 0.0035952893 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.673       |
# |    explained_variance   | -0.0728      |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00435     |
# |    n_updates            | 200          |
# |    policy_gradient_loss | -0.00919     |
# |    value_loss           | 0.0255       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 243          |
# |    ep_rew_mean          | 0.184        |
# | time/                   |              |
# |    fps                  | 446          |
# |    iterations           | 22           |
# |    time_elapsed         | 3            |
# |    total_timesteps      | 1408         |
# | train/                  |              |
# |    approx_kl            | 0.0019497848 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.655       |
# |    explained_variance   | -0.0306      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.76e-05     |
# |    n_updates            | 210          |
# |    policy_gradient_loss | -0.00229     |
# |    value_loss           | 0.0221       |
# ------------------------------------------
# --------------------------------------------
# | rollout/                |                |
# |    ep_len_mean          | 243            |
# |    ep_rew_mean          | 0.0102         |
# | time/                   |                |
# |    fps                  | 444            |
# |    iterations           | 23             |
# |    time_elapsed         | 3              |
# |    total_timesteps      | 1472           |
# | train/                  |                |
# |    approx_kl            | 0.000100011006 |
# |    clip_fraction        | 0              |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -0.647         |
# |    explained_variance   | -0.0469        |
# |    learning_rate        | 0.0003         |
# |    loss                 | 0.0048         |
# |    n_updates            | 220            |
# |    policy_gradient_loss | -0.00247       |
# |    value_loss           | 0.0349         |
# --------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 243          |
# |    ep_rew_mean          | 0.0102       |
# | time/                   |              |
# |    fps                  | 444          |
# |    iterations           | 24           |
# |    time_elapsed         | 3            |
# |    total_timesteps      | 1536         |
# | train/                  |              |
# |    approx_kl            | 0.0038403631 |
# |    clip_fraction        | 0.00313      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.629       |
# |    explained_variance   | -0.0512      |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0116      |
# |    n_updates            | 230          |
# |    policy_gradient_loss | -0.0106      |
# |    value_loss           | 0.0599       |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 243         |
# |    ep_rew_mean          | 0.0102      |
# | time/                   |             |
# |    fps                  | 443         |
# |    iterations           | 25          |
# |    time_elapsed         | 3           |
# |    total_timesteps      | 1600        |
# | train/                  |             |
# |    approx_kl            | 0.008667469 |
# |    clip_fraction        | 0.0281      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.596      |
# |    explained_variance   | -0.0149     |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0296     |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.00837    |
# |    value_loss           | 0.0349      |
# -----------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 243           |
# |    ep_rew_mean          | 0.0102        |
# | time/                   |               |
# |    fps                  | 443           |
# |    iterations           | 26            |
# |    time_elapsed         | 3             |
# |    total_timesteps      | 1664          |
# | train/                  |               |
# |    approx_kl            | 0.00051496783 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.574        |
# |    explained_variance   | 0.00707       |
# |    learning_rate        | 0.0003        |
# |    loss                 | 0.0135        |
# |    n_updates            | 250           |
# |    policy_gradient_loss | -0.0012       |
# |    value_loss           | 0.0517        |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 243          |
# |    ep_rew_mean          | 0.0559       |
# | time/                   |              |
# |    fps                  | 443          |
# |    iterations           | 27           |
# |    time_elapsed         | 3            |
# |    total_timesteps      | 1728         |
# | train/                  |              |
# |    approx_kl            | 0.0013701222 |
# |    clip_fraction        | 0.00156      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.553       |
# |    explained_variance   | -0.0682      |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.000126    |
# |    n_updates            | 260          |
# |    policy_gradient_loss | -0.00862     |
# |    value_loss           | 0.0311       |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 243         |
# |    ep_rew_mean          | 0.0559      |
# | time/                   |             |
# |    fps                  | 443         |
# |    iterations           | 28          |
# |    time_elapsed         | 4           |
# |    total_timesteps      | 1792        |
# | train/                  |             |
# |    approx_kl            | 0.009096597 |
# |    clip_fraction        | 0.0312      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.516      |
# |    explained_variance   | -0.148      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00337    |
# |    n_updates            | 270         |
# |    policy_gradient_loss | -0.0128     |
# |    value_loss           | 0.0458      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 243          |
# |    ep_rew_mean          | 0.0559       |
# | time/                   |              |
# |    fps                  | 442          |
# |    iterations           | 29           |
# |    time_elapsed         | 4            |
# |    total_timesteps      | 1856         |
# | train/                  |              |
# |    approx_kl            | 0.0006936947 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.468       |
# |    explained_variance   | -0.000847    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0247       |
# |    n_updates            | 280          |
# |    policy_gradient_loss | -0.00373     |
# |    value_loss           | 0.125        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 243          |
# |    ep_rew_mean          | 0.0559       |
# | time/                   |              |
# |    fps                  | 442          |
# |    iterations           | 30           |
# |    time_elapsed         | 4            |
# |    total_timesteps      | 1920         |
# | train/                  |              |
# |    approx_kl            | 0.0069879773 |
# |    clip_fraction        | 0.0516       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.511       |
# |    explained_variance   | -0.0482      |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.021       |
# |    n_updates            | 290          |
# |    policy_gradient_loss | -0.00919     |
# |    value_loss           | 0.0218       |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 243         |
# |    ep_rew_mean          | 0.353       |
# | time/                   |             |
# |    fps                  | 441         |
# |    iterations           | 31          |
# |    time_elapsed         | 4           |
# |    total_timesteps      | 1984        |
# | train/                  |             |
# |    approx_kl            | 0.004400701 |
# |    clip_fraction        | 0.0141      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.492      |
# |    explained_variance   | -0.363      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.000765   |
# |    n_updates            | 300         |
# |    policy_gradient_loss | -0.00964    |
# |    value_loss           | 0.0283      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 243         |
# |    ep_rew_mean          | 0.353       |
# | time/                   |             |
# |    fps                  | 435         |
# |    iterations           | 32          |
# |    time_elapsed         | 4           |
# |    total_timesteps      | 2048        |
# | train/                  |             |
# |    approx_kl            | 0.004181523 |
# |    clip_fraction        | 0.0156      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.422      |
# |    explained_variance   | 0.0221      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0184      |
# |    n_updates            | 310         |
# |    policy_gradient_loss | -0.00532    |
# |    value_loss           | 0.0486      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 243         |
# |    ep_rew_mean          | 0.353       |
# | time/                   |             |
# |    fps                  | 435         |
# |    iterations           | 33          |
# |    time_elapsed         | 4           |
# |    total_timesteps      | 2112        |
# | train/                  |             |
# |    approx_kl            | 0.003750246 |
# |    clip_fraction        | 0.0156      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.399      |
# |    explained_variance   | -0.0864     |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0103     |
# |    n_updates            | 320         |
# |    policy_gradient_loss | -0.00619    |
# |    value_loss           | 0.0325      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 243          |
# |    ep_rew_mean          | 0.353        |
# | time/                   |              |
# |    fps                  | 434          |
# |    iterations           | 34           |
# |    time_elapsed         | 5            |
# |    total_timesteps      | 2176         |
# | train/                  |              |
# |    approx_kl            | 0.0001641321 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.382       |
# |    explained_variance   | 0.00486      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00826      |
# |    n_updates            | 330          |
# |    policy_gradient_loss | -0.00124     |
# |    value_loss           | 0.0277       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 243          |
# |    ep_rew_mean          | 0.427        |
# | time/                   |              |
# |    fps                  | 432          |
# |    iterations           | 35           |
# |    time_elapsed         | 5            |
# |    total_timesteps      | 2240         |
# | train/                  |              |
# |    approx_kl            | 0.0019891867 |
# |    clip_fraction        | 0.00156      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.401       |
# |    explained_variance   | 0.0152       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0168       |
# |    n_updates            | 340          |
# |    policy_gradient_loss | -0.00398     |
# |    value_loss           | 0.0581       |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 243           |
# |    ep_rew_mean          | 0.427         |
# | time/                   |               |
# |    fps                  | 433           |
# |    iterations           | 36            |
# |    time_elapsed         | 5             |
# |    total_timesteps      | 2304          |
# | train/                  |               |
# |    approx_kl            | 0.00051827123 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.407        |
# |    explained_variance   | -0.156        |
# |    learning_rate        | 0.0003        |
# |    loss                 | 0.0171        |
# |    n_updates            | 350           |
# |    policy_gradient_loss | -0.0028       |
# |    value_loss           | 0.0462        |
# -------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 243         |
# |    ep_rew_mean          | 0.427       |
# | time/                   |             |
# |    fps                  | 432         |
# |    iterations           | 37          |
# |    time_elapsed         | 5           |
# |    total_timesteps      | 2368        |
# | train/                  |             |
# |    approx_kl            | 0.018099084 |
# |    clip_fraction        | 0.0781      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.389      |
# |    explained_variance   | 0.0045      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0158     |
# |    n_updates            | 360         |
# |    policy_gradient_loss | -0.0203     |
# |    value_loss           | 0.0163      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 243          |
# |    ep_rew_mean          | 0.608        |
# | time/                   |              |
# |    fps                  | 432          |
# |    iterations           | 38           |
# |    time_elapsed         | 5            |
# |    total_timesteps      | 2432         |
# | train/                  |              |
# |    approx_kl            | 0.0007628505 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.319       |
# |    explained_variance   | -0.0766      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00431      |
# |    n_updates            | 370          |
# |    policy_gradient_loss | -0.00256     |
# |    value_loss           | 0.0115       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 243          |
# |    ep_rew_mean          | 0.608        |
# | time/                   |              |
# |    fps                  | 432          |
# |    iterations           | 39           |
# |    time_elapsed         | 5            |
# |    total_timesteps      | 2496         |
# | train/                  |              |
# |    approx_kl            | 0.0044141533 |
# |    clip_fraction        | 0.0484       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.383       |
# |    explained_variance   | 0.0296       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0235       |
# |    n_updates            | 380          |
# |    policy_gradient_loss | -0.00806     |
# |    value_loss           | 0.0892       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 243          |
# |    ep_rew_mean          | 0.608        |
# | time/                   |              |
# |    fps                  | 432          |
# |    iterations           | 40           |
# |    time_elapsed         | 5            |
# |    total_timesteps      | 2560         |
# | train/                  |              |
# |    approx_kl            | 0.0018555373 |
# |    clip_fraction        | 0.00469      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.355       |
# |    explained_variance   | -0.00422     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0101       |
# |    n_updates            | 390          |
# |    policy_gradient_loss | -0.00247     |
# |    value_loss           | 0.036        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 243          |
# |    ep_rew_mean          | 0.608        |
# | time/                   |              |
# |    fps                  | 432          |
# |    iterations           | 41           |
# |    time_elapsed         | 6            |
# |    total_timesteps      | 2624         |
# | train/                  |              |
# |    approx_kl            | 0.0006438121 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.36        |
# |    explained_variance   | 0.0983       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00238     |
# |    n_updates            | 400          |
# |    policy_gradient_loss | -0.00457     |
# |    value_loss           | 0.0391       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 243          |
# |    ep_rew_mean          | 0.817        |
# | time/                   |              |
# |    fps                  | 431          |
# |    iterations           | 42           |
# |    time_elapsed         | 6            |
# |    total_timesteps      | 2688         |
# | train/                  |              |
# |    approx_kl            | 0.0040393984 |
# |    clip_fraction        | 0.0125       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.358       |
# |    explained_variance   | -0.175       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00557     |
# |    n_updates            | 410          |
# |    policy_gradient_loss | -0.00844     |
# |    value_loss           | 0.0383       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 243          |
# |    ep_rew_mean          | 0.817        |
# | time/                   |              |
# |    fps                  | 431          |
# |    iterations           | 43           |
# |    time_elapsed         | 6            |
# |    total_timesteps      | 2752         |
# | train/                  |              |
# |    approx_kl            | 0.0064849188 |
# |    clip_fraction        | 0.0328       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.376       |
# |    explained_variance   | 0.0886       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0237       |
# |    n_updates            | 420          |
# |    policy_gradient_loss | -0.0135      |
# |    value_loss           | 0.0943       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 243          |
# |    ep_rew_mean          | 0.817        |
# | time/                   |              |
# |    fps                  | 431          |
# |    iterations           | 44           |
# |    time_elapsed         | 6            |
# |    total_timesteps      | 2816         |
# | train/                  |              |
# |    approx_kl            | 0.0009133299 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.444       |
# |    explained_variance   | -0.372       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0271       |
# |    n_updates            | 430          |
# |    policy_gradient_loss | -0.00349     |
# |    value_loss           | 0.0915       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 243          |
# |    ep_rew_mean          | 0.817        |
# | time/                   |              |
# |    fps                  | 431          |
# |    iterations           | 45           |
# |    time_elapsed         | 6            |
# |    total_timesteps      | 2880         |
# | train/                  |              |
# |    approx_kl            | 0.0006998973 |
# |    clip_fraction        | 0.00156      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.463       |
# |    explained_variance   | 0.108        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.000995    |
# |    n_updates            | 440          |
# |    policy_gradient_loss | -0.00515     |
# |    value_loss           | 0.0309       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 243          |
# |    ep_rew_mean          | 0.996        |
# | time/                   |              |
# |    fps                  | 431          |
# |    iterations           | 46           |
# |    time_elapsed         | 6            |
# |    total_timesteps      | 2944         |
# | train/                  |              |
# |    approx_kl            | 0.0037677758 |
# |    clip_fraction        | 0.0141       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.438       |
# |    explained_variance   | -0.346       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00554      |
# |    n_updates            | 450          |
# |    policy_gradient_loss | -0.00863     |
# |    value_loss           | 0.058        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 243          |
# |    ep_rew_mean          | 0.996        |
# | time/                   |              |
# |    fps                  | 430          |
# |    iterations           | 47           |
# |    time_elapsed         | 6            |
# |    total_timesteps      | 3008         |
# | train/                  |              |
# |    approx_kl            | 0.0020449692 |
# |    clip_fraction        | 0.00625      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.401       |
# |    explained_variance   | 0.0724       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0226       |
# |    n_updates            | 460          |
# |    policy_gradient_loss | -0.00549     |
# |    value_loss           | 0.076        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 243          |
# |    ep_rew_mean          | 0.996        |
# | time/                   |              |
# |    fps                  | 429          |
# |    iterations           | 48           |
# |    time_elapsed         | 7            |
# |    total_timesteps      | 3072         |
# | train/                  |              |
# |    approx_kl            | 0.0010700431 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.446       |
# |    explained_variance   | -0.212       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0115      |
# |    n_updates            | 470          |
# |    policy_gradient_loss | -0.00558     |
# |    value_loss           | 0.0387       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 243          |
# |    ep_rew_mean          | 0.996        |
# | time/                   |              |
# |    fps                  | 425          |
# |    iterations           | 49           |
# |    time_elapsed         | 7            |
# |    total_timesteps      | 3136         |
# | train/                  |              |
# |    approx_kl            | 0.0014326433 |
# |    clip_fraction        | 0.00469      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.439       |
# |    explained_variance   | -0.288       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0146      |
# |    n_updates            | 480          |
# |    policy_gradient_loss | -0.00894     |
# |    value_loss           | 0.0402       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 243          |
# |    ep_rew_mean          | 1.15         |
# | time/                   |              |
# |    fps                  | 425          |
# |    iterations           | 50           |
# |    time_elapsed         | 7            |
# |    total_timesteps      | 3200         |
# | train/                  |              |
# |    approx_kl            | 0.0067350846 |
# |    clip_fraction        | 0.0187       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.432       |
# |    explained_variance   | -0.0317      |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.000732    |
# |    n_updates            | 490          |
# |    policy_gradient_loss | -0.00972     |
# |    value_loss           | 0.035        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 243          |
# |    ep_rew_mean          | 1.15         |
# | time/                   |              |
# |    fps                  | 424          |
# |    iterations           | 51           |
# |    time_elapsed         | 7            |
# |    total_timesteps      | 3264         |
# | train/                  |              |
# |    approx_kl            | 0.0009901356 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.44        |
# |    explained_variance   | 0.0134       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0735       |
# |    n_updates            | 500          |
# |    policy_gradient_loss | -0.00389     |
# |    value_loss           | 0.186        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 243         |
# |    ep_rew_mean          | 1.15        |
# | time/                   |             |
# |    fps                  | 424         |
# |    iterations           | 52          |
# |    time_elapsed         | 7           |
# |    total_timesteps      | 3328        |
# | train/                  |             |
# |    approx_kl            | 0.009500278 |
# |    clip_fraction        | 0.0328      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.465      |
# |    explained_variance   | 0.114       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0445     |
# |    n_updates            | 510         |
# |    policy_gradient_loss | -0.0112     |
# |    value_loss           | 0.00961     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 243          |
# |    ep_rew_mean          | 1.15         |
# | time/                   |              |
# |    fps                  | 425          |
# |    iterations           | 53           |
# |    time_elapsed         | 7            |
# |    total_timesteps      | 3392         |
# | train/                  |              |
# |    approx_kl            | 0.0028148526 |
# |    clip_fraction        | 0.00937      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.43        |
# |    explained_variance   | -0.444       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0019       |
# |    n_updates            | 520          |
# |    policy_gradient_loss | -0.00505     |
# |    value_loss           | 0.0203       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 243          |
# |    ep_rew_mean          | 1.26         |
# | time/                   |              |
# |    fps                  | 425          |
# |    iterations           | 54           |
# |    time_elapsed         | 8            |
# |    total_timesteps      | 3456         |
# | train/                  |              |
# |    approx_kl            | 0.0028144238 |
# |    clip_fraction        | 0.00937      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.381       |
# |    explained_variance   | 0.0158       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0166       |
# |    n_updates            | 530          |
# ...
# |    ep_len_mean          | 243          |
# |    ep_rew_mean          | 3.63         |
# | time/                   |              |
# |    fps                  | 370          |
# |    iterations           | 296          |
# |    time_elapsed         | 51           |
# |    total_timesteps      | 18944        |
# | train/                  |              |
# |    approx_kl            | 0.0016264445 |
# |    clip_fraction        | 0.00625      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.247       |
# |    explained_variance   | 0.0508       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00768     |
# |    n_updates            | 2950         |
# |    policy_gradient_loss | -0.00409     |
# |    value_loss           | 0.0281       |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 243         |
# |    ep_rew_mean          | 3.65        |
# | time/                   |             |
# |    fps                  | 370         |
# |    iterations           | 297         |
# |    time_elapsed         | 51          |
# |    total_timesteps      | 19008       |
# | train/                  |             |
# |    approx_kl            | 0.001420238 |
# |    clip_fraction        | 0.00469     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.137      |
# |    explained_variance   | 0.288       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0216      |
# |    n_updates            | 2960        |
# |    policy_gradient_loss | -0.00198    |
# |    value_loss           | 0.0713      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 243          |
# |    ep_rew_mean          | 3.65         |
# | time/                   |              |
# |    fps                  | 369          |
# |    iterations           | 298          |
# |    time_elapsed         | 51           |
# |    total_timesteps      | 19072        |
# | train/                  |              |
# |    approx_kl            | 0.0011184514 |
# |    clip_fraction        | 0.00156      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.153       |
# |    explained_variance   | 0.0952       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0776       |
# |    n_updates            | 2970         |
# |    policy_gradient_loss | -0.00322     |
# |    value_loss           | 0.175        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 243          |
# |    ep_rew_mean          | 3.65         |
# | time/                   |              |
# |    fps                  | 370          |
# |    iterations           | 299          |
# |    time_elapsed         | 51           |
# |    total_timesteps      | 19136        |
# | train/                  |              |
# |    approx_kl            | 0.0074673835 |
# |    clip_fraction        | 0.0203       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.21        |
# |    explained_variance   | -0.532       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00269     |
# |    n_updates            | 2980         |
# |    policy_gradient_loss | -0.0087      |
# |    value_loss           | 0.0704       |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 243         |
# |    ep_rew_mean          | 3.66        |
# | time/                   |             |
# |    fps                  | 369         |
# |    iterations           | 300         |
# |    time_elapsed         | 51          |
# |    total_timesteps      | 19200       |
# | train/                  |             |
# |    approx_kl            | 0.008879026 |
# |    clip_fraction        | 0.0859      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.217      |
# |    explained_variance   | -0.254      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00868    |
# |    n_updates            | 2990        |
# |    policy_gradient_loss | -0.0135     |
# |    value_loss           | 0.0198      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 243          |
# |    ep_rew_mean          | 3.66         |
# | time/                   |              |
# |    fps                  | 369          |
# |    iterations           | 301          |
# |    time_elapsed         | 52           |
# |    total_timesteps      | 19264        |
# | train/                  |              |
# |    approx_kl            | 0.0028317617 |
# |    clip_fraction        | 0.0156       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.142       |
# |    explained_variance   | 0.108        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0586       |
# |    n_updates            | 3000         |
# |    policy_gradient_loss | -0.00481     |
# |    value_loss           | 0.156        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 243         |
# |    ep_rew_mean          | 3.66        |
# | time/                   |             |
# |    fps                  | 369         |
# |    iterations           | 302         |
# |    time_elapsed         | 52          |
# |    total_timesteps      | 19328       |
# | train/                  |             |
# |    approx_kl            | 0.002217506 |
# |    clip_fraction        | 0.0109      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.163      |
# |    explained_variance   | -0.0575     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0191      |
# |    n_updates            | 3010        |
# |    policy_gradient_loss | -0.00432    |
# |    value_loss           | 0.0419      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 243         |
# |    ep_rew_mean          | 3.66        |
# | time/                   |             |
# |    fps                  | 369         |
# |    iterations           | 303         |
# |    time_elapsed         | 52          |
# |    total_timesteps      | 19392       |
# | train/                  |             |
# |    approx_kl            | 0.003244435 |
# |    clip_fraction        | 0.0125      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.229      |
# |    explained_variance   | 0.227       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00145     |
# |    n_updates            | 3020        |
# |    policy_gradient_loss | -0.00679    |
# |    value_loss           | 0.0558      |
# -----------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 243           |
# |    ep_rew_mean          | 3.67          |
# | time/                   |               |
# |    fps                  | 369           |
# |    iterations           | 304           |
# |    time_elapsed         | 52            |
# |    total_timesteps      | 19456         |
# | train/                  |               |
# |    approx_kl            | 0.00097642234 |
# |    clip_fraction        | 0.00313       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.179        |
# |    explained_variance   | -0.384        |
# |    learning_rate        | 0.0003        |
# |    loss                 | -0.00169      |
# |    n_updates            | 3030          |
# |    policy_gradient_loss | -0.0032       |
# |    value_loss           | 0.0313        |
# -------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 243         |
# |    ep_rew_mean          | 3.67        |
# | time/                   |             |
# |    fps                  | 368         |
# |    iterations           | 305         |
# |    time_elapsed         | 52          |
# |    total_timesteps      | 19520       |
# | train/                  |             |
# |    approx_kl            | 0.012912157 |
# |    clip_fraction        | 0.0531      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.144      |
# |    explained_variance   | 0.153       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0989      |
# |    n_updates            | 3040        |
# |    policy_gradient_loss | -0.00734    |
# |    value_loss           | 0.184       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 243          |
# |    ep_rew_mean          | 3.67         |
# | time/                   |              |
# |    fps                  | 368          |
# |    iterations           | 306          |
# |    time_elapsed         | 53           |
# |    total_timesteps      | 19584        |
# | train/                  |              |
# |    approx_kl            | 0.0003977595 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.149       |
# |    explained_variance   | 0.0417       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00287      |
# |    n_updates            | 3050         |
# |    policy_gradient_loss | -0.00222     |
# |    value_loss           | 0.0371       |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 243         |
# |    ep_rew_mean          | 3.67        |
# | time/                   |             |
# |    fps                  | 368         |
# |    iterations           | 307         |
# |    time_elapsed         | 53          |
# |    total_timesteps      | 19648       |
# | train/                  |             |
# |    approx_kl            | 0.007184017 |
# |    clip_fraction        | 0.0266      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.24       |
# |    explained_variance   | -0.0907     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00197     |
# |    n_updates            | 3060        |
# |    policy_gradient_loss | -0.00728    |
# |    value_loss           | 0.0466      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 243         |
# |    ep_rew_mean          | 3.69        |
# | time/                   |             |
# |    fps                  | 368         |
# |    iterations           | 308         |
# |    time_elapsed         | 53          |
# |    total_timesteps      | 19712       |
# | train/                  |             |
# |    approx_kl            | 0.007248573 |
# |    clip_fraction        | 0.0187      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.137      |
# |    explained_variance   | 0.068       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0134      |
# |    n_updates            | 3070        |
# |    policy_gradient_loss | -0.00817    |
# |    value_loss           | 0.0789      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 243          |
# |    ep_rew_mean          | 3.69         |
# | time/                   |              |
# |    fps                  | 368          |
# |    iterations           | 309          |
# |    time_elapsed         | 53           |
# |    total_timesteps      | 19776        |
# | train/                  |              |
# |    approx_kl            | 0.0007206844 |
# |    clip_fraction        | 0.00156      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.151       |
# |    explained_variance   | 0.158        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0922       |
# |    n_updates            | 3080         |
# |    policy_gradient_loss | -0.00033     |
# |    value_loss           | 0.264        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 243          |
# |    ep_rew_mean          | 3.69         |
# | time/                   |              |
# |    fps                  | 368          |
# |    iterations           | 310          |
# |    time_elapsed         | 53           |
# |    total_timesteps      | 19840        |
# | train/                  |              |
# |    approx_kl            | 0.0010442622 |
# |    clip_fraction        | 0.00313      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.151       |
# |    explained_variance   | 0.225        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00642      |
# |    n_updates            | 3090         |
# |    policy_gradient_loss | -0.00151     |
# |    value_loss           | 0.0704       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 243          |
# |    ep_rew_mean          | 3.69         |
# | time/                   |              |
# |    fps                  | 367          |
# |    iterations           | 311          |
# |    time_elapsed         | 54           |
# |    total_timesteps      | 19904        |
# | train/                  |              |
# |    approx_kl            | 0.0045904615 |
# |    clip_fraction        | 0.0453       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.251       |
# |    explained_variance   | -0.927       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0307       |
# |    n_updates            | 3100         |
# |    policy_gradient_loss | -0.011       |
# |    value_loss           | 0.0946       |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 243         |
# |    ep_rew_mean          | 3.7         |
# | time/                   |             |
# |    fps                  | 367         |
# |    iterations           | 312         |
# |    time_elapsed         | 54          |
# |    total_timesteps      | 19968       |
# | train/                  |             |
# |    approx_kl            | 0.005776236 |
# |    clip_fraction        | 0.0344      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.134      |
# |    explained_variance   | 0.0598      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0059      |
# |    n_updates            | 3110        |
# |    policy_gradient_loss | -0.00902    |
# |    value_loss           | 0.0973      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 243         |
# |    ep_rew_mean          | 3.7         |
# | time/                   |             |
# |    fps                  | 367         |
# |    iterations           | 313         |
# |    time_elapsed         | 54          |
# |    total_timesteps      | 20032       |
# | train/                  |             |
# |    approx_kl            | 0.007991228 |
# |    clip_fraction        | 0.0359      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.128      |
# |    explained_variance   | 0.202       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.102       |
# |    n_updates            | 3120        |
# |    policy_gradient_loss | -0.00884    |
# |    value_loss           | 0.246       |
# -----------------------------------------

# %%
obs, _ = env.reset()
done = False

total_reward = 0

while not done:
    action, _ = model.predict(obs)
    obs, reward, done, _, _ = env.step(action)
    total_reward += reward

print("Final Balance:", env.balance)
print("Total Reward:", total_reward)
# Out:
# Final Balance: 99.26465982831341
# Total Reward: 5.465412499784765
