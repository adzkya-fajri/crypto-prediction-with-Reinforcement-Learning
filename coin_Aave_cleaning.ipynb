# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv ("coin_Aave.csv")

# %%
data.isna().sum()
# Out:
# SNo          0
# Name         0
# Symbol       0
# Date         0
# High         0
# Low          0
# Open         0
# Close        0
# Volume       0
# Marketcap    0
# dtype: int64
